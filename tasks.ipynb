# %%
# task 1
import pandas as pd
FIFA=pd.read_csv("fifa19 (1).csv")

# %%
# task 2
entries=FIFA.columns[0:12]
print(FIFA[entries]);
# or 
# FIFA.head(11)
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
# task 3
print(FIFA.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
# task 4
print(len(FIFA))
# Out:
# 18207

# %%
# task 5
for i in FIFA:
    print(i)
# Out:
# Unnamed: 0
# ID
# Name
# Age
# Photo
# Nationality
# Flag
# Overall
# Potential
# Club
# Club Logo
# Value
# Wage
# Special
# Preferred Foot
# International Reputation
# Weak Foot
# Skill Moves
# Work Rate
# Body Type
# Real Face
# Position
# Jersey Number
# Joined
# Loaned From
# Contract Valid Until
# Height
# Weight
# LS
# ST
# RS
# LW
# LF
# CF
# RF
# RW
# LAM
# CAM
# RAM
# LM
# LCM
# CM
# RCM
# RM
# LWB
# LDM
# CDM
# RDM
# RWB
# LB
# LCB
# CB
# RCB
# RB
# Crossing
# Finishing
# HeadingAccuracy
# ShortPassing
# Volleys
# Dribbling
# Curve
# FKAccuracy
# LongPassing
# BallControl
# Acceleration
# SprintSpeed
# Agility
# Reactions
# Balance
# ShotPower
# Jumping
# Stamina
# Strength
# LongShots
# Aggression
# Interceptions
# Positioning
# Vision
# Penalties
# Composure
# Marking
# StandingTackle
# SlidingTackle
# GKDiving
# GKHandling
# GKKicking
# GKPositioning
# GKReflexes
# Release Clause

# %%
# task 6
print(FIFA.loc[5000])
# Out:
# Unnamed: 0                                                  5000
# ID                                                        227394
# Name                                                 C. González
# Age                                                           25
# Photo             https://cdn.sofifa.org/players/4/19/227394.png
#                                        ...
# GKHandling                                                   6.0
# GKKicking                                                   13.0
# GKPositioning                                               13.0
# GKReflexes                                                   7.0
# Release Clause                                             €4.1M
# Name: 5000, Length: 89, dtype: object

# %%
# task 7
user_id=FIFA.columns[1]
print(FIFA[user_id])
# Out:
# 0        158023
# 1         20801
# 2        190871
# 3        193080
# 4        192985
#           ...
# 18202    238813
# 18203    243165
# 18204    241638
# 18205    246268
# 18206    246269
# Name: ID, Length: 18207, dtype: int64

# %%
FIFA.select_dtypes(include="object")
# Out:
#                      Name                                           Photo  \
# 0                L. Messi  https://cdn.sofifa.org/players/4/19/158023.png
# 1       Cristiano Ronaldo   https://cdn.sofifa.org/players/4/19/20801.png
# 2               Neymar Jr  https://cdn.sofifa.org/players/4/19/190871.png
# 3                  De Gea  https://cdn.sofifa.org/players/4/19/193080.png
# 4            K. De Bruyne  https://cdn.sofifa.org/players/4/19/192985.png
# ...                   ...                                             ...
# 18202        J. Lundstram  https://cdn.sofifa.org/players/4/19/238813.png
# 18203  N. Christoffersson  https://cdn.sofifa.org/players/4/19/243165.png
# 18204           B. Worman  https://cdn.sofifa.org/players/4/19/241638.png
# 18205      D. Walker-Rice  https://cdn.sofifa.org/players/4/19/246268.png
# 18206           G. Nugent  https://cdn.sofifa.org/players/4/19/246269.png
#
#       Nationality                                 Flag                 Club  \
# ...

# %%
FIFA.dtypes
# Out:
# Unnamed: 0          int64
# ID                  int64
# Name               object
# Age                 int64
# Photo              object
#                    ...
# GKHandling        float64
# GKKicking         float64
# GKPositioning     float64
# GKReflexes        float64
# Release Clause     object
# Length: 89, dtype: object

# %%
# task 8
for i in FIFA.select_dtypes(exclude='number').columns:
    FIFA[i]=list(map(lambda x:x.strip() if type(x)==str else x, FIFA[i]))

# %%
FIFA.sort_values(["Club","Name"]).head()
# Out:
#        Unnamed: 0      ID         Name  Age  \
# 4812         4812  183565     A. Feick   30
# 9890         9890  200954  D. Thomalla   25
# 15318       15318  243975     G. Kılıç   18
# 17538       17538  245515   J. Brändle   18
# 12004       12004  238065  K. Lankford   19
#
#                                                 Photo Nationality  \
# 4812   https://cdn.sofifa.org/players/4/19/183565.png     Germany
# 9890   https://cdn.sofifa.org/players/4/19/200954.png     Germany
# 15318  https://cdn.sofifa.org/players/4/19/243975.png     Germany
# 17538  https://cdn.sofifa.org/players/4/19/245515.png     Germany
# 12004  https://cdn.sofifa.org/players/4/19/238065.png     Germany
#
#                                       Flag  Overall  Potential  \
# 4812   https://cdn.sofifa.org/flags/21.png       70         70
# 9890   https://cdn.sofifa.org/flags/21.png       66         69
# 15318  https://cdn.sofifa.org/flags/21.png       59         76
# ...

# %%
FIFA.Club.value_counts()
# Out:
# FC Barcelona                 33
# Valencia CF                  33
# Fortuna Düsseldorf           33
# Cardiff City                 33
# Rayo Vallecano               33
#                              ..
# América FC (Minas Gerais)    20
# Fluminense                   20
# Sligo Rovers                 19
# Limerick FC                  19
# Derry City                   18
# Name: Club, Length: 651, dtype: int64

# %%
# task 9
Overall=FIFA["Overall"]>90
print(FIFA[Overall])
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
# 5           5  183277          E. Hazard   27
# 6           6  177003          L. Modrić   32
# 7           7  176580          L. Suárez   31
# 8           8  155862       Sergio Ramos   32
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# 6  https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# ...

# %%
# task 10
print(FIFA.columns)
FIFA=FIFA.drop('Unnamed: 0',axis=1)
print(FIFA.columns)
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
# task 11
print(len(FIFA.Position.unique()))
# Out:
# 28

# %%
# task 12
print(FIFA.isnull().sum())
# Out:
# ID                   0
# Name                 0
# Age                  0
# Photo                0
# Nationality          0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 88, dtype: int64

# %%
# task 13
# FIFA[FIFA.columns[-1]].isnull()="unknown"
FIFA[FIFA.columns[-1]].fillna(value="Unknown",inplace=True)
print(FIFA.isnull().sum())
# Out:
# Unnamed: 0         0
# ID                 0
# Name               0
# Age                0
# Photo              0
#                   ..
# GKHandling        48
# GKKicking         48
# GKPositioning     48
# GKReflexes        48
# Release Clause     0
# Length: 89, dtype: int64

# %%
# task 14
print(FIFA.Age.mean())
# Out:
# 25.122205745043114

# %%
# task 15
max_score=FIFA.ShotPower.max()
print(max_score)
# Out:
# 95.0

# %%
# task 16
footballer=FIFA.Name[FIFA.ShotPower.max()]
print(footballer," : ",max_score)
# Out:
# J. Boateng  :  95.0

# %%
# task 17

FIFA.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...
